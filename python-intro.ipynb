# %%
age=43
name="Tracie"
last_name="Beuden"

# %%
print(name, "will be", age+10, "in ten years.")
# Out:
# Tracie will be 53 in ten years.

# %%
print(name[2]
      )
# Out:
# a

# %%
print(name[0])
# Out:
# T

# %%
name_substring= name[0:3]
print(name_substring)
# Out:
# Tra

# %%
length_name = len(name)

# %%
print(length_name + 4)
# Out:
# 10

# %%
sueyrcbew=0

# %%
Sueyrcbew=5

# %%
name="Trace"

# %%
print(name)
# Out:
# Trace

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
new_age="17"
print(new_age +15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-2b8f550c3d8d> in <cell line: 0>()
#       1 new_age="17"
# ----> 2 print(new_age +15)
#
# TypeError: can only concatenate str (not "int") to str

# %%
new_age=int(new_age)

# %%
print(new_age+15)
# Out:
# 32

# %%
num=3.14

# %%
type(num)
# Out:
# float

# %%
num- 0.14
# Out:
# 3.0

# %%
num*2
# Out:
# 6.28

# %%
num/3.14
# Out:
# 1.0

# %%
integer=4
type(integer/3)
# Out:
# float

# %%
name*2
# Out:
# 'TraceTrace'

# %%
name+2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-37c5e497494c> in <cell line: 0>()
# ----> 1 name+2
#
# TypeError: can only concatenate str (not "int") to str

# %%
name+"."
# Out:
# 'Trace.'

# %%
#comments aren't executed

# %%
print ("hello world")
print()
print ("hello", "world", "again")
# Out:
# hello world
#
# hello world again

# %%
result = print("example")
print("result of print is", result)
# Out:
# example
# result of print is None

# %%
print(max(0,1,2,3))
print(min("a", "A", "0"))
# Out:
# 3
# 0

# %%
round(3.14159, 3)
# Out:
# 3.142

# %%
my_string="Hello world!"
print(len(my_string)) #Print the length of my string
print(my_string.swapcase()) #swapcase is like a function, so it needs parentheses
# Out:
# 12
# hELLO WORLD!

# %%
print(my_string.isupper())
print(my_string.upper())
# Out:
# False
# HELLO WORLD!

# %%
print(my_string.upper().isupper()) #strings are immutable
# Out:
# True

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
1 radiance=1.0
2 radiance=max(2.1, 2.0 +min(radiance, 1.1*radiance-0.5))
3 radiance

# %%
import math

print("pi is", math.pi)
print("cos(pi) is", math.cos(math.pi))
# Out:
# pi is 3.141592653589793
# cos(pi) is -1.0

# %%
from math import cos, pi

print("cos(pi) is", cos(pi))
import sklearn
# Out:
# cos(pi) is -1.0

# %%
import pandas as pd

# %%
data_oceania= pd.read_csv("data/gapminder_gdp_oceania.csv", index_col="country")
print(data_oceania)
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data_oceania.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gdpPercap_1952  2 non-null      float64
#  1   gdpPercap_1957  2 non-null      float64
#  2   gdpPercap_1962  2 non-null      float64
#  3   gdpPercap_1967  2 non-null      float64
#  4   gdpPercap_1972  2 non-null      float64
#  5   gdpPercap_1977  2 non-null      float64
#  6   gdpPercap_1982  2 non-null      float64
#  7   gdpPercap_1987  2 non-null      float64
#  8   gdpPercap_1992  2 non-null      float64
#  9   gdpPercap_1997  2 non-null      float64
#  10  gdpPercap_2002  2 non-null      float64
#  11  gdpPercap_2007  2 non-null      float64
# dtypes: float64(12)
# memory usage: 316.0+ bytes

# %%
print(data_oceania.columns)
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
print(data_oceania.T)
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
#! means batch
# !mk dir data_2
# !mv *.csv data_2
# !ls data
# Out:
# /bin/bash: line 1: mk: command not found
# mv: cannot stat '*.csv': No such file or directory
# gapminder_all.csv	  gapminder_gdp_americas.csv  gapminder_gdp_europe.csv
# gapminder_gdp_africa.csv  gapminder_gdp_asia.csv      gapminder_gdp_oceania.csv

# %%
data_americas= pd.read_csv("data/gapminder_gdp_americas.csv", index_col="country")
print(data_americas)
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
help(data_americas.head)
help(data_americas.tail)
# Out:
# Help on method head in module pandas.core.generic:
#
# head(n: 'int' = 5) -> 'Self' method of pandas.core.frame.DataFrame instance
#     Return the first `n` rows.
#
#     This function returns the first `n` rows for the object based
#     on position. It is useful for quickly testing if your object
#     has the right type of data in it.
#
#     For negative values of `n`, this function returns all rows except
#     the last `|n|` rows, equivalent to ``df[:n]``.
#
#     If n is larger than the number of rows, this function returns all rows.
#
#     Parameters
#     ----------
#     n : int, default 5
#         Number of rows to select.
#
#     Returns
#     -------
#     same type as caller
#         The first `n` rows of the caller object.
#
#     See Also
#     --------
#     DataFrame.tail: Returns the last `n` rows.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'animal': ['alligator', 'bee', 'falcon', 'lion',
# ...

# %%
data_americas.head(3)
# Out:
#           continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
#
#            gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# Argentina     9139.671389     9308.418710    10967.281950     8797.640716
# Bolivia       2753.691490     2961.699694     3326.143191     3413.262690
# Brazil        7807.095818     6950.283021     7957.980824     8131.212843
#
#            gdpPercap_2007
# country
# Argentina    12779.379640
# ...

# %%
data_americas.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# ...

# %%
data_americas.iloc[0,0]
#integer location
# Out:
# 'Americas'

# %%
data_americas.loc["Argentina", "gdpPercap_1952"]
#location
#import numpyas np (numeric python)
# Out:
# np.float64(5911.315053)

# %%
print(data_americas.loc["Canada",  :])
#: means all columns in that row
# Out:
# continent            Americas
# gdpPercap_1952    11367.16112
# gdpPercap_1957    12489.95006
# gdpPercap_1962    13462.48555
# gdpPercap_1967    16076.58803
# gdpPercap_1972    18970.57086
# gdpPercap_1977    22090.88306
# gdpPercap_1982    22898.79214
# gdpPercap_1987    26626.51503
# gdpPercap_1992    26342.88426
# gdpPercap_1997    28954.92589
# gdpPercap_2002    33328.96507
# gdpPercap_2007    36319.23501
# Name: Canada, dtype: object

# %%
data = data_americas.drop("continent")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-775f8a84fca1> in <cell line: 0>()
# ----> 1 data = data_americas.drop("continent")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
data = data_americas.drop("continent", axis=1)
data.head()
# Out:
#            gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Argentina     5911.315053     6856.856212     7133.166023     8052.953021
# Bolivia       2677.326347     2127.686326     2180.972546     2586.886053
# Brazil        2108.944355     2487.365989     3336.585802     3429.864357
# Canada       11367.161120    12489.950060    13462.485550    16076.588030
# Chile         3939.978789     4315.622723     4519.094331     5106.654313
#
#            gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Argentina     9443.038526    10079.026740     8997.897412     9139.671389
# Bolivia       2980.331339     3548.097832     3156.510452     2753.691490
# Brazil        4985.711467     6660.118654     7030.835878     7807.095818
# Canada       18970.570860    22090.883060    22898.792140    26626.515030
# Chile         5494.024437     4756.763836     5095.665738     5547.063754
#
# ...

# %%
print(data_americas.loc[:, "gdpPercap_1952"])
#equivlent to print print(data_americas.loc["gdpPercap_1952"])
# Out:
# country
# Argentina               5911.315053
# Bolivia                 2677.326347
# Brazil                  2108.944355
# Canada                 11367.161120
# Chile                   3939.978789
# Colombia                2144.115096
# Costa Rica              2627.009471
# Cuba                    5586.538780
# Dominican Republic      1397.717137
# Ecuador                 3522.110717
# El Salvador             3048.302900
# Guatemala               2428.237769
# Haiti                   1840.366939
# Honduras                2194.926204
# Jamaica                 2898.530881
# Mexico                  3478.125529
# Nicaragua               3112.363948
# Panama                  2480.380334
# Paraguay                1952.308701
# Peru                    3758.523437
# Puerto Rico             3081.959785
# Trinidad and Tobago     3023.271928
# United States          13990.482080
# Uruguay                 5716.766744
# Venezuela               7689.799761
# Name: gdpPercap_1952, dtype: float64

# %%
#slices
data.loc["Canada":"Cuba", "gdpPercap_1962":"gdpPercap_1972"]
# Out:
#             gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Canada        13462.485550    16076.588030    18970.570860
# Chile          4519.094331     5106.654313     5494.024437
# Colombia       2492.351109     2678.729839     3264.660041
# Costa Rica     3460.937025     4161.727834     5118.146939
# Cuba           5180.755910     5690.268015     5305.445256

# %%
data.loc["Canada":"Cuba", "gdpPercap_1962":"gdpPercap_1972"].max()
# Out:
# gdpPercap_1962    13462.48555
# gdpPercap_1967    16076.58803
# gdpPercap_1972    18970.57086
# dtype: float64

# %%
data.loc["Canada":"Cuba", "gdpPercap_1962":"gdpPercap_1972"].min()
# Out:
# gdpPercap_1962    2492.351109
# gdpPercap_1967    2678.729839
# gdpPercap_1972    3264.660041
# dtype: float64

# %%
subset = data.loc["Canada":"Cuba", "gdpPercap_1962":"gdpPercap_1972"]

# %%
subset>10000
# Out:
#             gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Canada                True            True            True
# Chile                False           False           False
# Colombia             False           False           False
# Costa Rica           False           False           False
# Cuba                 False           False           False

# %%
mask=subset>10000
print(subset[mask])
#Nan numerical N/A "not a number"
# Out:
#             gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Canada         13462.48555     16076.58803     18970.57086
# Chile                  NaN             NaN             NaN
# Colombia               NaN             NaN             NaN
# Costa Rica             NaN             NaN             NaN
# Cuba                   NaN             NaN             NaN

# %%
subset[mask].describe()
# Out:
#        gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# count         1.00000         1.00000         1.00000
# mean      13462.48555     16076.58803     18970.57086
# std               NaN             NaN             NaN
# min       13462.48555     16076.58803     18970.57086
# 25%       13462.48555     16076.58803     18970.57086
# 50%       13462.48555     16076.58803     18970.57086
# 75%       13462.48555     16076.58803     18970.57086
# max       13462.48555     16076.58803     18970.57086

# %%
mask_higher-data>data.mean()
# Out:
#                      gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina                     False           False           False
# Bolivia                       False           False           False
# Brazil                        False           False           False
# Canada                        False           False           False
# Chile                         False           False           False
# Colombia                      False           False           False
# Costa Rica                    False           False           False
# Cuba                          False           False           False
# Dominican Republic            False           False           False
# Ecuador                       False           False           False
# El Salvador                   False           False           False
# Guatemala                     False           False           False
# Haiti                         False           False           False
# ...

# %%
mask_higher.aggregate("sum", axis=1)

# %%
data.mean()
# Out:
# gdpPercap_1952     4079.062552
# gdpPercap_1957     4616.043733
# gdpPercap_1962     4901.541870
# gdpPercap_1967     5668.253496
# gdpPercap_1972     6491.334139
# gdpPercap_1977     7352.007126
# gdpPercap_1982     7506.737088
# gdpPercap_1987     7793.400261
# gdpPercap_1992     8044.934406
# gdpPercap_1997     8889.300863
# gdpPercap_2002     9287.677107
# gdpPercap_2007    11003.031625
# dtype: float64

# %%
mask_higher-data>data.mean()
wealth_score=(mask_higher.aggregate("sum", axis=1)/
                                  len(data.columns))
print(wealth_score)
# Out:
# country
# Argentina              0.916667
# Bolivia                0.000000
# Brazil                 0.083333
# Canada                 1.000000
# Chile                  0.250000
# Colombia               0.000000
# Costa Rica             0.000000
# Cuba                   0.333333
# Dominican Republic     0.000000
# Ecuador                0.000000
# El Salvador            0.000000
# Guatemala              0.000000
# Haiti                  0.000000
# Honduras               0.000000
# Jamaica                0.333333
# Mexico                 0.750000
# Nicaragua              0.000000
# Panama                 0.000000
# Paraguay               0.000000
# Peru                   0.166667
# Puerto Rico            0.833333
# Trinidad and Tobago    0.500000
# United States          1.000000
# Uruguay                0.416667
# Venezuela              0.916667
# dtype: float64

# %%
print(mask_higher.aggregate("sum", axis=1))
# Out:
# country
# Argentina              11
# Bolivia                 0
# Brazil                  1
# Canada                 12
# Chile                   3
# Colombia                0
# Costa Rica              0
# Cuba                    4
# Dominican Republic      0
# Ecuador                 0
# El Salvador             0
# Guatemala               0
# Haiti                   0
# Honduras                0
# Jamaica                 4
# Mexico                  9
# Nicaragua               0
# Panama                  0
# Paraguay                0
# Peru                    2
# Puerto Rico            10
# Trinidad and Tobago     6
# United States          12
# Uruguay                 5
# Venezuela              11
# dtype: int64

# %%
data.groupby(wealth_score).sum()
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0.000000    29425.165563    31217.878662    33816.357910    38615.373437
# 0.083333     2108.944355     2487.365989     3336.585802     3429.864357
# 0.166667     3758.523437     4245.256698     4957.037982     5788.093330
# 0.250000     3939.978789     4315.622723     4519.094331     5106.654313
# 0.333333     8485.069661    10848.700140    10426.863434    11814.971466
# 0.416667     5716.766744     6150.772969     5603.357717     5444.619620
# 0.500000     3023.271928     4100.393400     4997.523971     5621.368472
# 0.750000     3478.125529     4131.546641     4581.609385     5754.733883
# 0.833333     3081.959785     3907.156189     5108.344630     6929.277714
# 0.916667    13601.114814    16659.322738    15556.140188    17594.427209
# 1.000000    25357.643200    27337.077180    29635.631410    35606.953600
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# ...

# %%
data.groupby(wealth_score).mean()
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0.000000     2452.097130     2601.489888     2818.029826     3217.947786
# 0.083333     2108.944355     2487.365989     3336.585802     3429.864357
# 0.166667     3758.523437     4245.256698     4957.037982     5788.093330
# 0.250000     3939.978789     4315.622723     4519.094331     5106.654313
# 0.333333     4242.534830     5424.350070     5213.431717     5907.485733
# 0.416667     5716.766744     6150.772969     5603.357717     5444.619620
# 0.500000     3023.271928     4100.393400     4997.523971     5621.368472
# 0.750000     3478.125529     4131.546641     4581.609385     5754.733883
# 0.833333     3081.959785     3907.156189     5108.344630     6929.277714
# 0.916667     6800.557407     8329.661369     7778.070094     8797.213605
# 1.000000    12678.821600    13668.538590    14817.815705    17803.476800
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# ...

# %%
data_all= pd.read_csv("data/gapminder_all.csv")
data_all.head()
# Out:
#   continent       country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Africa       Algeria     2449.008185     3013.976023     2550.816880
# 1    Africa        Angola     3520.610273     3827.940465     4269.276742
# 2    Africa         Benin     1062.752200      959.601080      949.499064
# 3    Africa      Botswana      851.241141      918.232535      983.653976
# 4    Africa  Burkina Faso      543.255241      617.183465      722.512021
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     3246.991771     4182.663766     4910.416756     5745.160213
# 1     5522.776375     5473.288005     3008.647355     2756.953672
# 2     1035.831411     1085.796879     1029.161251     1277.897616
# 3     1214.709294     2263.611114     3214.857818     4551.142150
# 4      794.826560      854.735976      743.387037      807.198586
#
#    gdpPercap_1987  ...    pop_1962    pop_1967    pop_1972    pop_1977  \
# ...

# %%
data_all[data_all["continent"]=="Africa"]
# Out:
#    continent                   country  gdpPercap_1952  gdpPercap_1957  \
# 0     Africa                   Algeria     2449.008185     3013.976023
# 1     Africa                    Angola     3520.610273     3827.940465
# 2     Africa                     Benin     1062.752200      959.601080
# 3     Africa                  Botswana      851.241141      918.232535
# 4     Africa              Burkina Faso      543.255241      617.183465
# 5     Africa                   Burundi      339.296459      379.564628
# 6     Africa                  Cameroon     1172.667655     1313.048099
# 7     Africa  Central African Republic     1071.310713     1190.844328
# 8     Africa                      Chad     1178.665927     1308.495577
# 9     Africa                   Comoros     1102.990936     1211.148548
# 10    Africa           Congo Dem. Rep.      780.542326      905.860230
# 11    Africa                Congo Rep.     2125.621418     2315.056572
# ...

# %%
data_all[data_all["continent"]=="Africa","gdpPercap_1952"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# Name: continent, Length: 142, dtype: bool, 'gdpPercap_1952')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-124-31d0878cfad6> in <cell line: 0>()
# ...

# %%
data_all.loc[data_all["continent"]=="Africa","gdpPercap_1952"].plot.bar()
# Out:
# <Axes: >

# %%
africa_data=data_all.loc[data_all["continent"]=="Africa"]

# %%
import matplotlib.pyplot as plt

# %%
data_all.loc[data_all["continent"]=="Africa","gdpPercap_1952"].plot.bar()

plt.xl
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-147-03f668034539> in <cell line: 0>()
#       1 data_all.loc[data_all["continent"]=="Africa","gdpPercap_1952"].plot.bar()
#       2
# ----> 3 plt.xl
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xl'

# %%
import numpy as np

# %%
africa_data["gdpPercap_1952"].plot.bar()
plt.xticks(np.arange(0,52,1),labels=africa_data["country"].values)
# Out:
# ([<matplotlib.axis.XTick at 0x7bcff4085210>,
# ...
#  [Text(0, 0, 'Algeria'),
#   Text(1, 0, 'Angola'),
#   Text(2, 0, 'Benin'),
#   Text(3, 0, 'Botswana'),
#   Text(4, 0, 'Burkina Faso'),
#   Text(5, 0, 'Burundi'),
#   Text(6, 0, 'Cameroon'),
#   Text(7, 0, 'Central African Republic'),
#   Text(8, 0, 'Chad'),
#   Text(9, 0, 'Comoros'),
#   Text(10, 0, 'Congo Dem. Rep.'),
#   Text(11, 0, 'Congo Rep.'),
#   Text(12, 0, "Cote d'Ivoire"),
#   Text(13, 0, 'Djibouti'),
#   Text(14, 0, 'Egypt'),
#   Text(15, 0, 'Equatorial Guinea'),
#   Text(16, 0, 'Eritrea'),
#   Text(17, 0, 'Ethiopia'),
#   Text(18, 0, 'Gabon'),
#   Text(19, 0, 'Gambia'),
#   Text(20, 0, 'Ghana'),
#   Text(21, 0, 'Guinea'),
#   Text(22, 0, 'Guinea-Bissau'),
#   Text(23, 0, 'Kenya'),
#   Text(24, 0, 'Lesotho'),
#   Text(25, 0, 'Liberia'),
#   Text(26, 0, 'Libya'),
#   Text(27, 0, 'Madagascar'),
#   Text(28, 0, 'Malawi'),
#   Text(29, 0, 'Mali'),
#   Text(30, 0, 'Mauritania'),
#   Text(31, 0, 'Mauritius'),
# ...
